# %%
# !pip install transformers datasets torchaudio jiwer
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.0)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchaudio) (2.5.1+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchaudio) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchaudio) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.9 MB/s eta 0:00:00
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 30.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, rapidfuzz, fsspec, dill, multiprocess, jiwer, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 jiwer-3.0.5 multiprocess-0.70.16 rapidfuzz-3.11.0 xxhash-3.5.0

# %%
#!/bin/bash
# !kaggle datasets download kynthesis/vivos-vietnamese-speech-corpus-for-asr
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kynthesis/vivos-vietnamese-speech-corpus-for-asr
# License(s): Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)
# Downloading vivos-vietnamese-speech-corpus-for-asr.zip to /content
# 100% 1.37G/1.37G [00:17<00:00, 89.8MB/s]
# 100% 1.37G/1.37G [00:17<00:00, 83.5MB/s]

# %%
# !unzip vivos-vietnamese-speech-corpus-for-asr.zip -d vivos-vietnamese-speech-corpus-for-asr
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_272.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_273.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_274.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_275.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_276.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_277.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_278.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_279.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_280.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_281.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_282.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_283.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_284.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_285.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_286.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_287.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_288.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_289.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_290.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_291.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_292.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_293.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_294.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_295.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_296.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_297.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_298.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_299.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK26/VIVOSSPK26_300.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_001.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_002.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_003.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_004.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_005.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_006.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_007.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_008.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_009.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_010.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_011.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_012.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_013.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_014.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_015.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_016.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_017.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_018.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_019.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_020.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_021.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_022.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_023.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_024.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_025.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_026.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_027.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_028.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_029.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_030.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_031.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_032.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_033.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_034.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_035.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_036.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_037.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_038.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_039.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_040.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_041.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_042.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_043.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_044.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_045.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_046.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_047.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_048.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_049.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_050.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_051.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_052.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_053.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_054.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_055.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_056.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_057.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_058.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_059.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_060.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_061.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_062.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_063.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_064.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_065.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_066.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_067.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_068.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_069.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_070.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_071.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_072.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_073.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_074.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_075.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_076.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_077.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_078.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_079.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_080.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_081.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_082.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_083.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_084.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_085.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_086.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_087.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_088.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_089.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_090.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_091.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_092.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_093.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_094.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_095.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_096.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_097.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_098.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_099.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_100.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_101.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_102.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_103.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_104.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_105.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_106.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_107.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_108.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_109.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_110.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_111.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_112.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_113.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_114.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_115.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_116.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_117.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_118.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_119.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_120.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_121.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_122.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_123.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_124.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_125.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_126.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_127.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_128.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_129.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_130.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_131.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_132.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_133.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_134.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_135.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_136.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_137.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_138.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_139.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_140.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_141.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_142.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_143.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_144.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_145.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_146.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_147.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_148.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_149.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_150.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_151.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_152.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_153.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_154.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_155.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_156.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_157.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_158.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_159.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_160.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_161.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_162.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_163.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_164.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_165.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_166.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_167.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_168.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_169.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_170.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_171.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_172.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_173.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_174.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_175.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_176.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_177.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_178.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_179.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_180.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_181.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_182.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_183.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_184.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_185.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_186.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_187.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_188.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_189.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_190.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_191.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_192.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_193.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_194.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_195.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_196.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_197.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_198.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_199.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_200.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_201.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_202.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_203.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_204.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_205.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_206.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_207.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_208.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_209.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_210.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_211.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_212.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_213.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_214.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_215.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_216.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_217.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_218.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_219.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_220.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_221.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_222.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_223.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_224.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_225.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_226.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_227.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_228.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_229.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_230.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_231.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_232.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_233.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_234.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_235.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_236.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_237.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_238.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_239.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_240.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_241.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_242.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_243.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK27/VIVOSSPK27_244.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_001.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_002.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_003.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_004.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_005.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_006.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_007.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_008.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_009.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_010.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_011.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_012.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_013.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_014.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_015.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_016.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_017.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_018.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_019.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_020.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_021.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_022.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_023.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_024.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_025.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_026.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_027.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_028.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_029.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_030.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_031.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_032.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_033.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_034.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_035.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_036.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_037.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_038.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_039.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_040.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_041.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_042.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_043.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_044.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_045.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_046.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_047.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_048.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_049.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_050.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_051.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_052.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_053.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_054.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_055.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_056.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_057.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_058.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_059.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_060.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_061.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_062.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_063.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_064.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_065.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_066.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_067.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_068.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_069.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_070.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_071.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_072.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_073.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_074.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_075.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_076.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_077.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_078.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_079.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_080.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_081.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_082.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_083.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_084.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_085.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_086.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_087.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_088.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_089.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_090.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_091.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_092.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_093.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_094.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_095.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_096.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_097.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_098.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_099.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_100.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_101.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_102.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_103.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_104.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_105.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_106.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_107.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_108.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_109.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_110.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_111.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_112.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_113.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_114.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_115.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_116.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_117.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_118.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_119.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_120.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_121.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_122.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_123.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_124.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_125.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_126.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_127.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_128.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_129.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_130.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_131.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_132.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_133.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_134.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_135.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_136.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_137.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_138.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_139.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_140.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_141.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_142.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_143.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_144.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_145.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_146.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_147.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_148.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_149.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_150.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_151.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_152.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_153.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_154.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_155.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_156.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_157.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_158.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_159.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_160.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_161.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_162.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_163.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_164.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_165.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_166.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_167.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_168.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_169.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK28/VIVOSSPK28_170.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_001.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_002.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_003.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_004.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_005.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_006.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_007.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_008.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_009.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_010.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_011.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_012.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_013.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_014.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_015.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_016.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_017.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_018.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_019.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_020.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_021.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_022.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_023.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_024.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_025.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_026.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK29/VIVOSSPK29_027.wav
# ...
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_145.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_146.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_147.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_148.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_149.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_150.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_151.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_152.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_153.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_154.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_155.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_156.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_157.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_158.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_159.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_160.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_161.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_162.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_163.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_164.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_165.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_166.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_167.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_168.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_169.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_170.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_171.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_172.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_173.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_174.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_175.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_176.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_177.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_178.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_179.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_180.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_181.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_182.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_183.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_184.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_185.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_186.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_187.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_188.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_189.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_190.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_191.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_192.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_193.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_194.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_195.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_196.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_197.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_198.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_199.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_200.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_201.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_202.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_203.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_204.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_205.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_206.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_207.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_208.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_209.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_210.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_211.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_212.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_213.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_214.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_215.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_216.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_217.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_218.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_219.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_220.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_221.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_222.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_223.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_224.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_225.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_226.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_227.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_228.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_229.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_230.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_231.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_232.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_233.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_234.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_235.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_236.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_237.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_238.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_239.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_240.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_241.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_242.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_243.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_244.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_245.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_246.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_247.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_248.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_249.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_250.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_251.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_252.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_253.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_254.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_255.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_256.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_257.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_258.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_259.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_260.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_261.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_262.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_263.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_264.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_265.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_266.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_267.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_268.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_269.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_270.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_271.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_272.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_273.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_274.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_275.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_276.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_277.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_278.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_279.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_280.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_281.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_282.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_283.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_284.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_285.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_286.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_287.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_288.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_289.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_290.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_291.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_292.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_293.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_294.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_295.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_296.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_297.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_298.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_299.wav
#   inflating: vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK46/VIVOSSPK46_300.wav

# %%
import os
from datasets import DatasetDict, Dataset

# Function to parse PROMPTS.txt and load data
def load_vivos_subset(subset_path):
    data = {"path": [], "transcription": []}
    prompts_path = os.path.join(subset_path, "prompts.txt")

    with open(prompts_path, "r", encoding="utf-8") as f:
        for line in f:
            # Split the line: first part is file path, the rest is transcription
            file_path, transcription = line.strip().split(" ", 1)

            # Extract the subdirectory name from the file_path
            speaker_folder = file_path.split("_")[0]  # e.g., "VIVOSSPK01"

            # Construct the correct file path
            audio_path = os.path.join(subset_path, "waves", speaker_folder, file_path + ".wav")

            data["path"].append(audio_path)
            data["transcription"].append(transcription)

    return Dataset.from_dict(data)

# Reload the dataset
def load_vivos_dataset(dataset_path):
    return DatasetDict({
        "train": load_vivos_subset(os.path.join(dataset_path, "train")),
        "test": load_vivos_subset(os.path.join(dataset_path, "test")),
    })

# Set dataset path and load
DATASET_PATH = "/content/vivos-vietnamese-speech-corpus-for-asr/vivos"
vivos = load_vivos_dataset(DATASET_PATH)

# Verify loaded data
print(vivos)
print(vivos["test"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'transcription'],
#         num_rows: 11660
#     })
#     test: Dataset({
#         features: ['path', 'transcription'],
#         num_rows: 760
#     })
# })
# {'path': '/content/vivos-vietnamese-speech-corpus-for-asr/vivos/test/waves/VIVOSDEV02/VIVOSDEV02_R106.wav', 'transcription': 'TRỞ NÊN THỤ ĐỘNG'}

# %%
# Import required libraries
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
from datasets import load_dataset, DatasetDict
from torchaudio.transforms import Resample
from jiwer import wer
import numpy as np
import torchaudio

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import torchaudio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import torch
from jiwer import wer  # For calculating Word Error Rate

# Set device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load Pre-trained Model and Processor
model = Wav2Vec2ForCTC.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h").to(device)
processor = Wav2Vec2Processor.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h")

# Function to preprocess audio
def preprocess_audio(path):
    # Load audio using torchaudio
    speech, sample_rate = torchaudio.load(path)

    # Resample to 16kHz if not already in the expected sample rate
    if sample_rate != 16000:
        transform = torchaudio.transforms.Resample(orig_freq=sample_rate,
                                                   new_freq=16000)
        speech = transform(speech)

    # Convert to a 1D array
    speech = speech.squeeze().numpy()
    return speech

# Test on the first input from the test set
test_sample = vivos["test"][0]  # Replace `vivos` with your DatasetDict variable
audio_path = test_sample["path"]
print(audio_path)
ground_truth = test_sample["transcription"]

# Preprocess the audio
speech = preprocess_audio(audio_path)

# Tokenize and make predictions
input_values = processor(speech, return_tensors="pt", sampling_rate=16000).input_values.to(device)
logits = model(input_values).logits
predicted_ids = torch.argmax(logits, dim=-1)

# Decode predictions to text
predicted_transcription = processor.batch_decode(predicted_ids)[0]

# Calculate Word Error Rate (WER)
error_rate = wer(ground_truth.lower(), predicted_transcription.lower())

# Output results
print(f"Ground Truth: {ground_truth}")
print(f"Predicted Transcription: {predicted_transcription}")
print(f"WER: {error_rate}")
# Out:
# config.json:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:311: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# /content/vivos-vietnamese-speech-corpus-for-asr/vivos/test/waves/VIVOSDEV02/VIVOSDEV02_R106.wav
# Ground Truth: TRỞ NÊN THỤ ĐỘNG
# Predicted Transcription: trở  nên thụ động
# WER: 0.0

# %%
vivos = load_vivos_dataset(DATASET_PATH)
for test_sample in vivos["test"]:
    audio_path = test_sample["path"]
    ground_truth = test_sample["transcription"]

    # Preprocess, predict, and evaluate like the second code
    speech = preprocess_audio(audio_path)
    input_values = processor(speech, return_tensors="pt", sampling_rate=16000).input_values.to(device)
    logits = model(input_values).logits
    predicted_ids = torch.argmax(logits, dim=-1)
    predicted_transcription = processor.batch_decode(predicted_ids)[0]

    print(f"Ground Truth: {ground_truth}")
    print(f"Predicted: {predicted_transcription}")
    print(f"WER: {wer(ground_truth.lower(), predicted_transcription.lower())}")
    break
# Out:
# Ground Truth: TRỞ NÊN THỤ ĐỘNG
# Predicted: trở  nên thụ động
# WER: 0.0

# %%
# # Clear RAM cache
# import gc
# gc.collect()
# torch.cuda.empty_cache()

# %%
vivos
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'transcription'],
#         num_rows: 11660
#     })
#     test: Dataset({
#         features: ['path', 'transcription'],
#         num_rows: 760
#     })
# })

# %%
# Import random for reproducibility
import random

# Define a seed for reproducibility
random.seed(42)

# Sample 1% of train and test splits
vivos = DatasetDict({
    "train": vivos["train"].select(random.sample(range(len(vivos["train"])), int(0.01 * len(vivos["train"])))),
    "test": vivos["test"].select(random.sample(range(len(vivos["test"])), int(0.01 * len(vivos["test"]))))
})

# Print the new dataset sizes
print(vivos)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'transcription'],
#         num_rows: 116
#     })
#     test: Dataset({
#         features: ['path', 'transcription'],
#         num_rows: 7
#     })
# })

# %%
vivos["train"][0]
# Out:
# {'path': '/content/vivos-vietnamese-speech-corpus-for-asr/vivos/train/waves/VIVOSSPK43/VIVOSSPK43_017.wav',
#  'transcription': 'CHÚNG GIÚP NGĂN NGỪA BỆNH TIM CHỐNG VIÊM KHỚP VÀ KÍCH THÍCH NÃO'}

# %%
import torch
from torch.utils.data import DataLoader
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
from torchaudio.transforms import Resample
import torchaudio
from jiwer import wer

# Initialize device and models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
processor = Wav2Vec2Processor.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h")
model = Wav2Vec2ForCTC.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h").to(device)

def preprocess_audio(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    resampler = Resample(sampling_rate, 16000)
    batch["speech"] = resampler(speech_array).squeeze().numpy()
    batch["sampling_rate"] = 16000
    return batch

def prepare_dataset(batch):
    # Process audio input
    inputs = processor(batch["speech"],
                      sampling_rate=batch["sampling_rate"],
                      return_tensors="pt",
                      padding=True)

    # Store the original transcription
    batch["input_values"] = inputs.input_values[0]
    batch["labels"] = batch["transcription"]  # Keep the original text
    return batch

def collate_fn(batch):
    # Process input values
    input_values = [torch.tensor(item["input_values"]) for item in batch]
    input_values = processor.pad(
        {"input_values": input_values},
        padding=True,
        return_tensors="pt"
    )["input_values"]

    # Keep original text labels
    labels = [item["labels"] for item in batch]

    return {
        "input_values": input_values,
        "labels": labels  # Return original text labels
    }

def evaluate(model, processor, data_loader):
    model.eval()
    predictions, references = [], []

    with torch.no_grad():
        for batch in data_loader:
            input_values = batch["input_values"].to(device)
            references.extend(batch["labels"])  # Use original text labels

            # Forward pass
            logits = model(input_values).logits
            pred_ids = torch.argmax(logits, dim=-1)
            predictions.extend(processor.batch_decode(pred_ids))

    # Calculate WER
    # Lower the array before calculate error rate
    references = [ref.lower() for ref in references]
    predictions = [pred.lower() for pred in predictions]
    wer_score = wer(references, predictions)
    return wer_score, predictions, references

# Process the dataset
vivos_processed = vivos.map(preprocess_audio)
vivos_prepared = vivos_processed.map(
    prepare_dataset,
    remove_columns=["speech", "sampling_rate", "path"]  # Keep transcription
)

# Create data loaders
train_loader = DataLoader(
    vivos_prepared["train"],
    batch_size=4,
    shuffle=True,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    vivos_prepared["test"],
    batch_size=4,
    collate_fn=collate_fn
)

# Evaluate
print("Evaluating model...")
wer_score, predictions, references = evaluate(model, processor, test_loader)
print(f"WER: {wer_score}")

# Print sample predictions
print("\nSample Predictions:")
for pred, ref in zip(predictions[:3], references[:3]):
    print(f"Reference: {ref}")
    print(f"Predicted: {pred}")
    print("-" * 50)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:311: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Map:   0%|          | 0/116 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7 [00:00<?, ? examples/s]
# Map:   0%|          | 0/116 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7 [00:00<?, ? examples/s]
# Evaluating model...
# WER: 0.13559322033898305
#
# Sample Predictions:
# Reference: ngủ trên nệm không phù hợp
# Predicted: ngủ trang niệm không phù hợp
# --------------------------------------------------
# Reference: hai mươi bốn hai mươi lăm
# Predicted: hai mươi bốn hai mươi lăm
# --------------------------------------------------
# Reference: gí hòn than vào rơm
# Predicted: guý hoàng thang vàu rươm
# --------------------------------------------------

# %%
for batch in train_loader:
    print(batch)
    print(len(batch['labels']))
    break
# Out:
# {'input_values': tensor([[ 2.9091e-06,  2.9091e-06, -4.1950e-04,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 2.0097e-01,  5.4827e-02,  1.6560e-03,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 1.0109e-07,  1.0109e-07,  1.0109e-07,  ..., -9.0240e-03,
#          -7.6356e-03, -9.3710e-03],
#         [-2.0010e-05, -2.0010e-05, -8.0151e-04,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00]]), 'labels': ['ĐÂU PHẢI LÀ BA CÁI CHUYỆN BE BÉ XINH XINH THẾ NÀY', 'TÔI TÌM MỌI CÁCH ĐỂ NÍU KÉO NHƯNG KHÔNG CÓ KẾT QUẢ', 'ĐỘI CỦA BỆNH VIỆN PHÁP VIỆT HÓA TRANG VỚI MÀU XANH ĐẶC TRƯNG CỦA MÌNH ẢNH MINH ĐỨC', 'NHIỀU HÃNG PHIM ĐÃ VÀO CUỘC ĐỂ ĐÒI QUYỀN LỢI CỦA MÌNH']}
# 4

# %%
import torch
import torch.nn as nn
from torch.optim import AdamW
from tqdm import tqdm
import os
from datetime import datetime

class CTCTrainer:
    def __init__(self, model, train_loader, test_loader, processor, device,
                 learning_rate=1e-4, num_epochs=10):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.processor = processor
        self.device = device
        self.num_epochs = num_epochs

        # Initialize optimizer and loss function
        self.optimizer = AdamW(model.parameters(), lr=learning_rate)
        self.criterion = nn.CTCLoss(blank=processor.tokenizer.pad_token_id)

        # Initialize best metrics for model saving
        self.best_wer = float('inf')

    def train_epoch(self):
        self.model.train()
        total_loss = 0
        progress_bar = tqdm(self.train_loader, desc='Training')

        for batch in progress_bar:
            # Move input to device
            input_values = batch["input_values"].to(self.device)

            # Clear gradients
            self.optimizer.zero_grad()

            # Forward pass
            outputs = self.model(input_values)
            logits = outputs.logits

            # Process labels batch by batch
            with self.processor.as_target_processor():
                labels_batch = []
                for text in batch["labels"]:
                    labels = self.processor(text).input_ids
                    labels_batch.append(labels)

            # Pad labels to the same length
            max_label_length = max(len(labels) for labels in labels_batch)
            padded_labels = torch.full((len(labels_batch), max_label_length),
                                    fill_value=self.processor.tokenizer.pad_token_id,
                                    device=self.device)

            label_lengths = []
            for i, labels in enumerate(labels_batch):
                label_length = len(labels)
                label_lengths.append(label_length)
                padded_labels[i, :label_length] = torch.tensor(labels, device=self.device)

            # Calculate input lengths
            input_lengths = torch.full(size=(logits.shape[0],),
                                    fill_value=logits.shape[1],
                                    device=self.device)

            # Convert label lengths to tensor
            label_lengths = torch.tensor(label_lengths, device=self.device)

            # Calculate loss
            loss = self.criterion(logits.transpose(0, 1), padded_labels,
                                input_lengths, label_lengths)

            # Backward pass
            loss.backward()
            self.optimizer.step()

            total_loss += loss.item()
            progress_bar.set_postfix({'loss': loss.item()})

        return total_loss / len(self.train_loader)

    def evaluate(self):
        self.model.eval()
        predictions, references = [], []

        with torch.no_grad():
            for batch in tqdm(self.test_loader, desc='Evaluating'):
                input_values = batch["input_values"].to(self.device)
                references.extend(batch["labels"])

                # Forward pass
                logits = self.model(input_values).logits
                pred_ids = torch.argmax(logits, dim=-1)
                predictions.extend(self.processor.batch_decode(pred_ids))

        # Calculate WER
        references = [ref.lower() for ref in references]
        predictions = [pred.lower() for pred in predictions]
        wer_score = wer(references, predictions)

        return wer_score, predictions, references

    def save_checkpoint(self, epoch, wer_score):
        # Create checkpoint directory if it doesn't exist
        checkpoint_dir = "checkpoints"
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        # Save model if it's the best so far
        if wer_score < self.best_wer:
            self.best_wer = wer_score
            checkpoint_path = os.path.join(
                checkpoint_dir,
                f"wav2vec2_vietnamese_epoch{epoch}_wer{wer_score:.4f}.pt"
            )

            # Save model state
            torch.save({
                'epoch': epoch,
                'model_state_dict': self.model.state_dict(),
                'optimizer_state_dict': self.optimizer.state_dict(),
                'wer': wer_score,
            }, checkpoint_path)

            print(f"\nSaved best model checkpoint to {checkpoint_path}")

    def train(self):
        print("Starting training...")

        # Get initial WER
        initial_wer, _, _ = self.evaluate()
        print(f"Initial WER: {initial_wer}")

        # Training loop
        for epoch in range(self.num_epochs):
            print(f"\nEpoch {epoch + 1}/{self.num_epochs}")

            # Train for one epoch
            avg_loss = self.train_epoch()
            print(f"Average loss: {avg_loss:.4f}")

            # Evaluate
            wer_score, predictions, references = self.evaluate()
            print(f"WER: {wer_score}")

            # Save checkpoint
            self.save_checkpoint(epoch + 1, wer_score)

            # Print some sample predictions
            print("\nSample Predictions:")
            for pred, ref in zip(predictions[:3], references[:3]):
                print(f"Reference: {ref}")
                print(f"Predicted: {pred}")
                print("-" * 50)

# Initialize trainer
trainer = CTCTrainer(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    processor=processor,
    device=device,
    learning_rate=1e-4,
    num_epochs=1
)

# Start training
trainer.train()

# Load best checkpoint and test
def load_best_model(model, checkpoint_dir="checkpoints"):
    checkpoints = [f for f in os.listdir(checkpoint_dir) if f.endswith('.pt')]
    best_checkpoint = min(checkpoints, key=lambda x: float(x.split('wer')[-1].split('.pt')[0]))
    checkpoint_path = os.path.join(checkpoint_dir, best_checkpoint)

    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"\nLoaded best model from {checkpoint_path}")
    print(f"Best WER: {checkpoint['wer']}")

    return model

# Test best model
best_model = load_best_model(model)
trainer.model = best_model
final_wer, final_predictions, final_references = trainer.evaluate()
print(f"\nFinal WER: {final_wer}")
# Out:
# Starting training...
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  5.64it/s]
# Initial WER: 0.13559322033898305
#
# Epoch 1/1
# Training:   0%|          | 0/29 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:174: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# Training: 100%|██████████| 29/29 [00:16<00:00,  1.71it/s, loss=-24.5]
# Average loss: -29.6267
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  4.64it/s]
# WER: 1.0
#
# Saved best model checkpoint to checkpoints/wav2vec2_vietnamese_epoch1_wer1.0000.pt
#
# Sample Predictions:
# Reference: ngủ trên nệm không phù hợp
# Predicted:
# --------------------------------------------------
# Reference: hai mươi bốn hai mươi lăm
# Predicted:
# --------------------------------------------------
# Reference: gí hòn than vào rơm
# Predicted:
# --------------------------------------------------
# <ipython-input-35-3bad1b7bed94>:175: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Loaded best model from checkpoints/wav2vec2_vietnamese_epoch1_wer1.0000.pt
# Best WER: 1.0
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  5.76it/s]
# Final WER: 1.0

# %%
import torch
import torch.nn as nn
from torch.optim import AdamW
from tqdm import tqdm
import os
from datetime import datetime
from jiwer import wer

class CTCTrainer:
    def __init__(self, model, train_loader, test_loader, processor, device,
                 learning_rate=1e-5,  # Reduced learning rate
                 num_epochs=10):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.processor = processor
        self.device = device
        self.num_epochs = num_epochs

        # Initialize optimizer with weight decay and lower learning rate
        self.optimizer = AdamW(model.parameters(),
                             lr=learning_rate,
                             weight_decay=0.01)  # Added weight decay

        # Initialize loss function with ignore_index
        self.criterion = nn.CTCLoss(blank=processor.tokenizer.pad_token_id,
                                  zero_infinity=True,
                                  reduction='mean')

        self.best_wer = float('inf')

    def train_epoch(self):
        self.model.train()
        total_loss = 0
        progress_bar = tqdm(self.train_loader, desc='Training')

        for batch_idx, batch in enumerate(progress_bar):
            # Move input to device
            input_values = batch["input_values"].to(self.device)

            # Clear gradients
            self.optimizer.zero_grad()

            # Forward pass
            outputs = self.model(input_values)
            logits = outputs.logits

            # Debug print logits statistics
            if batch_idx == 0:
                print("\nLogits statistics:")
                print("Mean:", logits.mean().item())
                print("Std:", logits.std().item())
                print("Max:", logits.max().item())
                print("Min:", logits.min().item())

            # Process labels
            with torch.no_grad():
                labels_batch = self.processor(text=batch["labels"],
                                           padding=True,
                                           return_tensors="pt")
                labels = labels_batch.input_ids.to(self.device)

                # Calculate input lengths from logits
                input_lengths = torch.full(
                    size=(logits.shape[0],),
                    fill_value=logits.shape[1],
                    dtype=torch.long,
                    device=self.device
                )

                # Calculate label lengths
                label_lengths = torch.sum(labels != self.processor.tokenizer.pad_token_id, dim=1)

            # Calculate loss with proper log_softmax
            log_probs = nn.functional.log_softmax(logits, dim=-1)
            log_probs = log_probs.transpose(0, 1)

            loss = self.criterion(log_probs, labels,
                                input_lengths, label_lengths)

            # Check for invalid loss
            if torch.isnan(loss) or torch.isinf(loss):
                print(f"Warning: Invalid loss {loss.item()} detected. Skipping batch.")
                continue

            # Backward pass with gradient clipping
            loss.backward()

            # Print gradient norms for debugging
            if batch_idx == 0:
                total_norm = 0.0
                for p in self.model.parameters():
                    if p.grad is not None:
                        param_norm = p.grad.data.norm(2)
                        total_norm += param_norm.item() ** 2
                total_norm = total_norm ** 0.5
                print(f"Gradient norm: {total_norm}")

            # Clip gradients
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)

            self.optimizer.step()

            total_loss += loss.item()
            progress_bar.set_postfix({'loss': loss.item()})

            # Add predictions debugging for first batch
            if batch_idx == 0:
                with torch.no_grad():
                    pred_ids = torch.argmax(logits, dim=-1)
                    print("\nSample predictions from batch:")
                    print("Pred_ids unique values:", torch.unique(pred_ids))
                    try:
                        predictions = self.processor.batch_decode(pred_ids)
                        print("First prediction:", predictions[0])
                    except Exception as e:
                        print("Decoding error:", str(e))

        return total_loss / len(self.train_loader)

    def evaluate(self):
        self.model.eval()
        predictions, references = [], []

        with torch.no_grad():
            for batch_idx, batch in enumerate(tqdm(self.test_loader, desc='Evaluating')):
                input_values = batch["input_values"].to(self.device)
                references.extend(batch["labels"])

                # Debug print for input shape
                print(f"\nBatch {batch_idx} debugging:")
                print("Input values shape:", input_values.shape)

                # Forward pass
                logits = self.model(input_values).logits
                print("Logits shape:", logits.shape)

                # Get predictions
                pred_ids = torch.argmax(logits, dim=-1)
                print("Pred_ids shape:", pred_ids.shape)
                print("First few pred_ids:", pred_ids[0, :10])  # Show first 10 predictions

                # Debug the processor decode step
                try:
                    pred_transcripts = self.processor.batch_decode(pred_ids)
                    print("Successfully decoded predictions")
                    print("First decoded transcript:", pred_transcripts[0] if pred_transcripts else "Empty")
                except Exception as e:
                    print("Error in batch_decode:", str(e))
                    # Try single sample decoding as fallback
                    pred_transcripts = []
                    for pred_id in pred_ids:
                        try:
                            transcript = self.processor.decode(pred_id)
                            print("Single decode result:", transcript)
                            pred_transcripts.append(transcript)
                        except Exception as e:
                            print("Error in single decode:", str(e))
                            pred_transcripts.append("")

                predictions.extend(pred_transcripts)

                # Debug print references and predictions
                print("\nFirst sample in batch:")
                print("Reference:", references[-len(pred_transcripts)])
                print("Predicted:", pred_transcripts[0] if pred_transcripts else "Empty")

        # Print overall statistics
        print("\nOverall statistics:")
        print(f"Total number of references: {len(references)}")
        print(f"Total number of predictions: {len(predictions)}")
        print("\nFirst few predictions:")
        for i in range(min(3, len(predictions))):
            print(f"Reference: {references[i]}")
            print(f"Predicted: {predictions[i]}")
            print("-" * 50)

        # Calculate WER
        references = [ref.lower() for ref in references]
        predictions = [pred.lower() for pred in predictions]
        wer_score = wer(references, predictions)

        return wer_score, predictions, references

    def save_checkpoint(self, epoch, wer_score):
        checkpoint_dir = "checkpoints"
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        if wer_score < self.best_wer:
            self.best_wer = wer_score
            checkpoint_path = os.path.join(
                checkpoint_dir,
                f"wav2vec2_vietnamese_epoch{epoch}_wer{wer_score:.4f}.pt"
            )

            torch.save({
                'epoch': epoch,
                'model_state_dict': self.model.state_dict(),
                'optimizer_state_dict': self.optimizer.state_dict(),
                'wer': wer_score,
            }, checkpoint_path)

            print(f"\nSaved best model checkpoint to {checkpoint_path}")

    def train(self):
        print("Starting training...")

        # Get initial WER
        initial_wer, _, _ = self.evaluate()
        print(f"Initial WER: {initial_wer}")

        for epoch in range(self.num_epochs):
            print(f"\nEpoch {epoch + 1}/{self.num_epochs}")

            # Train for one epoch
            avg_loss = self.train_epoch()
            print(f"Average loss: {avg_loss:.4f}")

            # Evaluate
            wer_score, predictions, references = self.evaluate()
            print(f"WER: {wer_score}")

            # Save checkpoint
            self.save_checkpoint(epoch + 1, wer_score)

            # Print some sample predictions
            print("\nSample Predictions:")
            for pred, ref in zip(predictions[:3], references[:3]):
                print(f"Reference: {ref}")
                print(f"Predicted: {pred}")
                print("-" * 50)

# Initialize trainer
trainer = CTCTrainer(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    processor=processor,
    device=device,
    learning_rate=1e-4,
    num_epochs=1
)

# Start training
trainer.train()

# Load best checkpoint and test
def load_best_model(model, checkpoint_dir="checkpoints"):
    checkpoints = [f for f in os.listdir(checkpoint_dir) if f.endswith('.pt')]
    best_checkpoint = min(checkpoints, key=lambda x: float(x.split('wer')[-1].split('.pt')[0]))
    checkpoint_path = os.path.join(checkpoint_dir, best_checkpoint)

    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"\nLoaded best model from {checkpoint_path}")
    print(f"Best WER: {checkpoint['wer']}")

    return model

# Test best model
best_model = load_best_model(model)
trainer.model = best_model
final_wer, final_predictions, final_references = trainer.evaluate()
print(f"\nFinal WER: {final_wer}")
# Out:
# Starting training...
# Evaluating:  50%|█████     | 1/2 [00:00<00:00,  2.84it/s]
# Batch 0 debugging:
# Input values shape: torch.Size([4, 54000])
# Logits shape: torch.Size([4, 168, 110])
# Pred_ids shape: torch.Size([4, 168])
# First few pred_ids: tensor([109, 109, 109, 109, 109, 109, 109, 109, 109, 109], device='cuda:0')
# Successfully decoded predictions
# First decoded transcript: ngủ trang niệm không phù hợp
#
# First sample in batch:
# Reference: NGỦ TRÊN NỆM KHÔNG PHÙ HỢP
# Predicted: ngủ trang niệm không phù hợp
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  3.13it/s]
# Batch 1 debugging:
# Input values shape: torch.Size([3, 62000])
# Logits shape: torch.Size([3, 193, 110])
# Pred_ids shape: torch.Size([3, 193])
# First few pred_ids: tensor([109, 109, 109, 109, 109, 109, 109, 109, 109, 109], device='cuda:0')
# Successfully decoded predictions
# First decoded transcript: cuộc biểu tình của áo đỏ có thể sẽ biến thành bạo lực
#
# First sample in batch:
# Reference: CUỘC BIỂU TÌNH CỦA ÁO ĐỎ CÓ THỂ SẼ BIẾN THÀNH BẠO LỰC
# Predicted: cuộc biểu tình của áo đỏ có thể sẽ biến thành bạo lực
#
# Overall statistics:
# Total number of references: 7
# Total number of predictions: 7
#
# First few predictions:
# Reference: NGỦ TRÊN NỆM KHÔNG PHÙ HỢP
# Predicted: ngủ trang niệm không phù hợp
# --------------------------------------------------
# Reference: HAI MƯƠI BỐN HAI MƯƠI LĂM
# Predicted: hai mươi bốn hai mươi lăm
# --------------------------------------------------
# Reference: GÍ HÒN THAN VÀO RƠM
# Predicted: guý hoàng thang vàu rươm
# --------------------------------------------------
# Initial WER: 0.13559322033898305
#
# Epoch 1/1
# Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Logits statistics:
# Mean: -4.597815036773682
# Std: 4.600584506988525
# Max: 15.41457748413086
# Min: -21.01230239868164
# Training:   3%|▎         | 1/29 [00:00<00:21,  1.30it/s, loss=13.1]
# Gradient norm: 34.603086331562714
#
# Sample predictions from batch:
# Pred_ids unique values: tensor([  3,   7,   8,   9,  12,  13,  15,  17,  18,  20,  24,  26,  30,  31,
#          32,  36,  40,  45,  46,  47,  49,  50,  52,  54,  56,  57,  58,  62,
#          67,  71,  72,  73,  79,  82,  83,  85,  88,  89,  92,  95,  96,  98,
#          99, 102, 105, 106, 109], device='cuda:0')
# First prediction: khi chạy lớn lên thình thoảng có thể có nước mắt chảy quay lỡ này
# Training: 100%|██████████| 29/29 [00:18<00:00,  1.55it/s, loss=0.654]
# Average loss: 1.9336
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Batch 0 debugging:
# Input values shape: torch.Size([4, 54000])
# Evaluating:  50%|█████     | 1/2 [00:00<00:00,  4.16it/s]
# Logits shape: torch.Size([4, 168, 110])
# Pred_ids shape: torch.Size([4, 168])
# First few pred_ids: tensor([109, 109, 109, 109, 109, 109, 109, 109, 109, 109], device='cuda:0')
# Successfully decoded predictions
# First decoded transcript:
#
# First sample in batch:
# Reference: NGỦ TRÊN NỆM KHÔNG PHÙ HỢP
# Predicted:
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# Batch 1 debugging:
# Input values shape: torch.Size([3, 62000])
# Logits shape: torch.Size([3, 193, 110])
# Pred_ids shape: torch.Size([3, 193])
# First few pred_ids: tensor([109, 109, 109, 109, 109, 109, 109, 109, 109, 109], device='cuda:0')
# Successfully decoded predictions
# First decoded transcript:
#
# First sample in batch:
# Reference: CUỘC BIỂU TÌNH CỦA ÁO ĐỎ CÓ THỂ SẼ BIẾN THÀNH BẠO LỰC
# Predicted:
#
# Overall statistics:
# Total number of references: 7
# Total number of predictions: 7
#
# First few predictions:
# Reference: NGỦ TRÊN NỆM KHÔNG PHÙ HỢP
# Predicted:
# --------------------------------------------------
# Reference: HAI MƯƠI BỐN HAI MƯƠI LĂM
# Predicted:
# --------------------------------------------------
# Reference: GÍ HÒN THAN VÀO RƠM
# Predicted:
# --------------------------------------------------
# WER: 1.0
# Saved best model checkpoint to checkpoints/wav2vec2_vietnamese_epoch1_wer1.0000.pt
#
# Sample Predictions:
# Reference: ngủ trên nệm không phù hợp
# Predicted:
# --------------------------------------------------
# Reference: hai mươi bốn hai mươi lăm
# Predicted:
# --------------------------------------------------
# Reference: gí hòn than vào rơm
# Predicted:
# --------------------------------------------------
# <ipython-input-33-803f9e0154de>:254: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Loaded best model from checkpoints/wav2vec2_vietnamese_epoch1_wer1.0000.pt
# Best WER: 1.0
# Evaluating:  50%|█████     | 1/2 [00:00<00:00,  5.34it/s]
# Batch 0 debugging:
# Input values shape: torch.Size([4, 54000])
# Logits shape: torch.Size([4, 168, 110])
# Pred_ids shape: torch.Size([4, 168])
# First few pred_ids: tensor([109, 109, 109, 109, 109, 109, 109, 109, 109, 109], device='cuda:0')
# Successfully decoded predictions
# First decoded transcript:
#
# First sample in batch:
# Reference: NGỦ TRÊN NỆM KHÔNG PHÙ HỢP
# Predicted:
#
# Batch 1 debugging:
# Input values shape: torch.Size([3, 62000])
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  5.51it/s]
# Logits shape: torch.Size([3, 193, 110])
# Pred_ids shape: torch.Size([3, 193])
# First few pred_ids: tensor([109, 109, 109, 109, 109, 109, 109, 109, 109, 109], device='cuda:0')
# Successfully decoded predictions
# First decoded transcript:
#
# First sample in batch:
# Reference: CUỘC BIỂU TÌNH CỦA ÁO ĐỎ CÓ THỂ SẼ BIẾN THÀNH BẠO LỰC
# Predicted:
#
# Overall statistics:
# Total number of references: 7
# Total number of predictions: 7
#
# First few predictions:
# Reference: NGỦ TRÊN NỆM KHÔNG PHÙ HỢP
# Predicted:
# --------------------------------------------------
# Reference: HAI MƯƠI BỐN HAI MƯƠI LĂM
# Predicted:
# --------------------------------------------------
# Reference: GÍ HÒN THAN VÀO RƠM
# Predicted:
# --------------------------------------------------
#
# Final WER: 1.0

# %%
class CTCTrainer:
    def __init__(self, model, train_loader, test_loader, processor, device,
                 learning_rate=1e-5,
                 num_epochs=1):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.processor = processor
        self.device = device
        self.num_epochs = num_epochs

        # Initialize optimizer with weight decay
        self.optimizer = AdamW(model.parameters(),
                             lr=learning_rate,
                             weight_decay=0.01)

        # Initialize CTC loss
        self.criterion = nn.CTCLoss(blank=processor.tokenizer.pad_token_id,
                                  zero_infinity=True)

        self.best_wer = float('inf')

    def train_epoch(self):
        self.model.train()
        total_loss = 0
        progress_bar = tqdm(self.train_loader, desc='Training')

        for batch_idx, batch in enumerate(progress_bar):
            # Move input to device
            input_values = batch["input_values"].to(self.device)

            # Clear gradients
            self.optimizer.zero_grad()

            # Forward pass
            outputs = self.model(input_values)
            print(f"Outputs shape: {outputs.logits.shape}")
            logits = outputs.logits
            print(f"Logits shape: {logits.shape}")

            # Process labels using processor
            with torch.no_grad():
                # Convert text to input IDs
                labels_batch = self.processor(
                    text=batch["labels"],
                    padding=True,
                    return_tensors="pt"
                )

                # Get input IDs and move to device
                labels = labels_batch.input_ids.to(self.device)

                # Calculate input lengths (from logits)
                input_lengths = torch.full(
                    size=(logits.shape[0],),
                    fill_value=logits.shape[1],
                    dtype=torch.long,
                    device=self.device
                )

                # Calculate label lengths (excluding padding)
                label_lengths = (labels != self.processor.tokenizer.pad_token_id).sum(dim=-1)

            # Apply log softmax
            log_probs = nn.functional.log_softmax(logits, dim=-1)
            print(f"Log probs shape: {log_probs.shape}")

            # Transpose log_probs for CTC loss (time, batch, class)
            log_probs = log_probs.transpose(0, 1)
            print(f"Transposed log probs shape: {log_probs.shape}")

            # Calculate CTC loss
            loss = self.criterion(log_probs, labels,
                                input_lengths, label_lengths)
            print(f"CTC Loss: {loss.item()}")

            # Skip invalid loss
            if torch.isnan(loss) or torch.isinf(loss):
                print(f"Warning: Invalid loss {loss.item()} detected. Skipping batch.")
                continue

            # Backward pass
            loss.backward()

            # Clip gradients
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)

            # Optimizer step
            self.optimizer.step()

            total_loss += loss.item()
            progress_bar.set_postfix({'loss': loss.item()})

        return total_loss / len(self.train_loader)

    def evaluate(self):
        self.model.eval()
        predictions, references = [], []

        with torch.no_grad():
            for batch in tqdm(self.test_loader, desc='Evaluating'):
                input_values = batch["input_values"].to(self.device)
                references.extend(batch["labels"])

                # Forward pass
                outputs = self.model(input_values)
                logits = outputs.logits

                # Get predictions
                pred_ids = torch.argmax(logits, dim=-1)

                # Decode predictions
                decoded_preds = self.processor.batch_decode(pred_ids)
                predictions.extend(decoded_preds)

        # Calculate WER
        references = [ref.lower() for ref in references]
        predictions = [pred.lower() for pred in predictions]
        wer_score = wer(references, predictions)

        return wer_score, predictions, references

    def train(self):
        print("Starting training...")

        # Get initial WER
        initial_wer, _, _ = self.evaluate()
        print(f"Initial WER: {initial_wer}")

        for epoch in range(self.num_epochs):
            print(f"\nEpoch {epoch + 1}/{self.num_epochs}")

            # Train epoch
            avg_loss = self.train_epoch()
            print(f"Average loss: {avg_loss:.4f}")

            # Evaluate
            wer_score, predictions, references = self.evaluate()
            print(f"WER: {wer_score}")

            # Print samples
            print("\nSample Predictions:")
            for pred, ref in zip(predictions[:3], references[:3]):
                print(f"Reference: {ref}")
                print(f"Predicted: {pred}")
                print("-" * 50)

# Initialize trainer with fixed implementation
trainer = CTCTrainer(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    processor=processor,
    device=device,
    learning_rate=1e-5,  # Lower learning rate
    num_epochs=1  # Increase epochs
)

# Start training
trainer.train()
# Out:
# Starting training...
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Decoded predictions: ['ngủ trang niệm không phù hợp', 'hai mươi bốn hai mươi lăm', 'guý hoàng thang vàu rươm', 'trận chiến xích bích']
# Decoded predictions: ['cuộc biểu tình của áo đỏ có thể sẽ biến thành bạo lực', 'vì vậy công ty bê phải có trách nhiệm bồi thường', 'họ cũng luôn tránh xa những tình huống có thể gây hại cho họ']
# Initial WER: 0.13559322033898305
#
# Epoch 1/1
# Training:   0%|          | 0/29 [00:00<?, ?it/s]
# Outputs shape: torch.Size([4, 324, 110])
# Logits shape: torch.Size([4, 324, 110])
# Log probs shape: torch.Size([4, 324, 110])
# Transposed log probs shape: torch.Size([324, 4, 110])
# CTC Loss: 12.591304779052734
# Outputs shape: torch.Size([4, 276, 110])
# Logits shape: torch.Size([4, 276, 110])
# Log probs shape: torch.Size([4, 276, 110])
# Transposed log probs shape: torch.Size([276, 4, 110])
# CTC Loss: 11.592634201049805
# Outputs shape: torch.Size([4, 190, 110])
# Logits shape: torch.Size([4, 190, 110])
# Log probs shape: torch.Size([4, 190, 110])
# Transposed log probs shape: torch.Size([190, 4, 110])
# CTC Loss: 10.232593536376953
# Outputs shape: torch.Size([4, 162, 110])
# Logits shape: torch.Size([4, 162, 110])
# Log probs shape: torch.Size([4, 162, 110])
# Transposed log probs shape: torch.Size([162, 4, 110])
# CTC Loss: 11.128286361694336
# Outputs shape: torch.Size([4, 306, 110])
# Logits shape: torch.Size([4, 306, 110])
# Log probs shape: torch.Size([4, 306, 110])
# Transposed log probs shape: torch.Size([306, 4, 110])
# CTC Loss: 11.603300094604492
# Outputs shape: torch.Size([4, 356, 110])
# Logits shape: torch.Size([4, 356, 110])
# Log probs shape: torch.Size([4, 356, 110])
# Transposed log probs shape: torch.Size([356, 4, 110])
# CTC Loss: 10.792333602905273
# Outputs shape: torch.Size([4, 334, 110])
# Logits shape: torch.Size([4, 334, 110])
# Log probs shape: torch.Size([4, 334, 110])
# Transposed log probs shape: torch.Size([334, 4, 110])
# CTC Loss: 10.394174575805664
# Outputs shape: torch.Size([4, 437, 110])
# Logits shape: torch.Size([4, 437, 110])
# Log probs shape: torch.Size([4, 437, 110])
# Transposed log probs shape: torch.Size([437, 4, 110])
# CTC Loss: 9.144505500793457
# Outputs shape: torch.Size([4, 259, 110])
# Logits shape: torch.Size([4, 259, 110])
# Log probs shape: torch.Size([4, 259, 110])
# Transposed log probs shape: torch.Size([259, 4, 110])
# CTC Loss: 8.71254825592041
# Outputs shape: torch.Size([4, 343, 110])
# Logits shape: torch.Size([4, 343, 110])
# Log probs shape: torch.Size([4, 343, 110])
# Transposed log probs shape: torch.Size([343, 4, 110])
# CTC Loss: 7.666688919067383
# Outputs shape: torch.Size([4, 531, 110])
# Logits shape: torch.Size([4, 531, 110])
# Log probs shape: torch.Size([4, 531, 110])
# Transposed log probs shape: torch.Size([531, 4, 110])
# CTC Loss: 6.921738624572754
# Outputs shape: torch.Size([4, 240, 110])
# Logits shape: torch.Size([4, 240, 110])
# Log probs shape: torch.Size([4, 240, 110])
# Transposed log probs shape: torch.Size([240, 4, 110])
# CTC Loss: 6.1674346923828125
# Outputs shape: torch.Size([4, 249, 110])
# Logits shape: torch.Size([4, 249, 110])
# Log probs shape: torch.Size([4, 249, 110])
# Transposed log probs shape: torch.Size([249, 4, 110])
# CTC Loss: 5.768461227416992
# Outputs shape: torch.Size([4, 171, 110])
# Logits shape: torch.Size([4, 171, 110])
# Log probs shape: torch.Size([4, 171, 110])
# Transposed log probs shape: torch.Size([171, 4, 110])
# CTC Loss: 5.38726282119751
# Outputs shape: torch.Size([4, 154, 110])
# Logits shape: torch.Size([4, 154, 110])
# Log probs shape: torch.Size([4, 154, 110])
# Transposed log probs shape: torch.Size([154, 4, 110])
# CTC Loss: 5.7410078048706055
# Outputs shape: torch.Size([4, 327, 110])
# Logits shape: torch.Size([4, 327, 110])
# Log probs shape: torch.Size([4, 327, 110])
# Transposed log probs shape: torch.Size([327, 4, 110])
# CTC Loss: 4.997804641723633
# Outputs shape: torch.Size([4, 391, 110])
# Logits shape: torch.Size([4, 391, 110])
# Log probs shape: torch.Size([4, 391, 110])
# Transposed log probs shape: torch.Size([391, 4, 110])
# CTC Loss: 4.649482727050781
# Outputs shape: torch.Size([4, 270, 110])
# Logits shape: torch.Size([4, 270, 110])
# Log probs shape: torch.Size([4, 270, 110])
# Transposed log probs shape: torch.Size([270, 4, 110])
# CTC Loss: 5.226876258850098
# Outputs shape: torch.Size([4, 252, 110])
# Logits shape: torch.Size([4, 252, 110])
# Log probs shape: torch.Size([4, 252, 110])
# Transposed log probs shape: torch.Size([252, 4, 110])
# CTC Loss: 3.316615581512451
# Outputs shape: torch.Size([4, 315, 110])
# Logits shape: torch.Size([4, 315, 110])
# Log probs shape: torch.Size([4, 315, 110])
# Transposed log probs shape: torch.Size([315, 4, 110])
# CTC Loss: 2.6685826778411865
# Outputs shape: torch.Size([4, 307, 110])
# Logits shape: torch.Size([4, 307, 110])
# Log probs shape: torch.Size([4, 307, 110])
# Transposed log probs shape: torch.Size([307, 4, 110])
# CTC Loss: 2.5968198776245117
# Outputs shape: torch.Size([4, 206, 110])
# Logits shape: torch.Size([4, 206, 110])
# Log probs shape: torch.Size([4, 206, 110])
# Transposed log probs shape: torch.Size([206, 4, 110])
# CTC Loss: 4.780604362487793
# Outputs shape: torch.Size([4, 206, 110])
# Logits shape: torch.Size([4, 206, 110])
# Log probs shape: torch.Size([4, 206, 110])
# Transposed log probs shape: torch.Size([206, 4, 110])
# CTC Loss: 4.773545265197754
# Outputs shape: torch.Size([4, 206, 110])
# Logits shape: torch.Size([4, 206, 110])
# Log probs shape: torch.Size([4, 206, 110])
# Transposed log probs shape: torch.Size([206, 4, 110])
# CTC Loss: 3.1675281524658203
# Outputs shape: torch.Size([4, 368, 110])
# Logits shape: torch.Size([4, 368, 110])
# Log probs shape: torch.Size([4, 368, 110])
# Transposed log probs shape: torch.Size([368, 4, 110])
# CTC Loss: 2.6438193321228027
# Outputs shape: torch.Size([4, 196, 110])
# Logits shape: torch.Size([4, 196, 110])
# Log probs shape: torch.Size([4, 196, 110])
# Transposed log probs shape: torch.Size([196, 4, 110])
# CTC Loss: 2.3840787410736084
# Outputs shape: torch.Size([4, 268, 110])
# Logits shape: torch.Size([4, 268, 110])
# Log probs shape: torch.Size([4, 268, 110])
# Transposed log probs shape: torch.Size([268, 4, 110])
# CTC Loss: 2.0212225914001465
# Outputs shape: torch.Size([4, 262, 110])
# Logits shape: torch.Size([4, 262, 110])
# Log probs shape: torch.Size([4, 262, 110])
# Transposed log probs shape: torch.Size([262, 4, 110])
# CTC Loss: 2.2602930068969727
# Outputs shape: torch.Size([4, 340, 110])
# Logits shape: torch.Size([4, 340, 110])
# Log probs shape: torch.Size([4, 340, 110])
# Transposed log probs shape: torch.Size([340, 4, 110])
# CTC Loss: 2.259140968322754
# Average loss: 6.2617
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Decoded predictions: ['<unk><unk><unk>', '<unk><unk>', '<unk><unk><unk><unk><unk><unk>', '<unk><unk><unk><unk><unk><unk><unk><unk>']
# Decoded predictions: ['<unk><unk>cbểuaàbạ<unk>', '<unk>mờ<unk><unk><unk><unk><unk><unk><unk><unk>', '<unk>ngnngạ<unk>']
# WER: 1.0
#
# Sample Predictions:
# Reference: ngủ trên nệm không phù hợp
# Predicted: <unk><unk><unk>
# --------------------------------------------------
# Reference: hai mươi bốn hai mươi lăm
# Predicted: <unk><unk>
# --------------------------------------------------
# Reference: gí hòn than vào rơm
# Predicted: <unk><unk><unk><unk><unk><unk>
# --------------------------------------------------
